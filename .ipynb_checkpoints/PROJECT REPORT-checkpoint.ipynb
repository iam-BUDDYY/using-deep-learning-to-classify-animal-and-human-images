# %% [markdown]
# **Báo cáo cuối kỳ môn học: PYTHON CHO KHOA HỌC DỮ LIỆU**
#
# **Lớp 23TTH Khoa Toán - Tin học**
#
# **Đề tài thực hiện:**
# \begin{center}
#     \textbf{USING DEEP LEARING TO CLASSIFY ANIMAL AND HUMAN IMAGES}
# \end{center}
#
# **Giảng viên hướng dẫn: ThS. Hà Văn Thảo**
#
# **Danh sách thành viên nhóm:**
# \begin{enumerate}
#   \item 23110114 - Nguyễn Thị Hồng Thắm
#   \item 23110123 - Lê Huỳnh Yến Vy
#   \item 23110132 - Trần Nhật Anh
# \end{enumerate}
#
# # GIỚI THIỆU

# %%
print("Hello World")

# %%
import torch
print("Torch:", torch.__version__)
print("CUDA built:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("GPU:", torch.cuda.device(0) if torch.cuda.is_available() else "None")
# Out:
# Torch: 2.9.1+cu128
# CUDA built: 12.8
# CUDA available: True
# GPU: NVIDIA GeForce GTX 1650
# GPU: <torch.cuda.device object at 0x7f4324b77ac0>

# %%
import ultralytics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import ultralytics
#
# ModuleNotFoundError: No module named 'ultralytics'
