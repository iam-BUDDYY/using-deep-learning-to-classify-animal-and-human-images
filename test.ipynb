# %%
import pandas as pd

# %%
data = pd.read_csv("runs/yolo11m/epochs80_imgsz640_optimization0/results.csv", \
                 usecols=["metrics/mAP50(B)", "metrics/mAP50-95(B)"]
                ).to_numpy()
print(data)
# Out:
# [[0.21907 0.1573 ]
#  [0.12453 0.08007]
#  [0.03541 0.01789]
#  [0.09203 0.05447]
#  [0.14498 0.09614]
#  [0.19672 0.13513]
#  [0.23911 0.16821]
#  [0.26831 0.19075]
#  [0.29379 0.21535]
#  [0.34718 0.25835]
#  [0.37296 0.27947]
#  [0.38432 0.28839]
#  [0.42077 0.31977]
#  [0.43934 0.34193]
#  [0.45865 0.35863]
#  [0.47085 0.36622]
#  [0.48654 0.37919]
#  [0.51781 0.4067 ]
#  [0.53985 0.42893]
#  [0.54344 0.4344 ]
#  [0.5597  0.44667]
#  [0.57026 0.45952]
#  [0.5755  0.46315]
#  [0.59376 0.48047]
#  [0.60338 0.49029]
#  [0.62097 0.50405]
#  [0.6232  0.50884]
#  [0.63308 0.51459]
#  [0.64049 0.52302]
#  [0.64791 0.52954]
#  [0.64514 0.53111]
#  [0.6512  0.53637]
#  [0.65162 0.53789]
#  [0.66193 0.54896]
#  [0.66804 0.55307]
#  [0.67112 0.55608]
#  [0.67292 0.55786]
#  [0.67462 0.55918]
#  [0.6769  0.56134]
#  [0.6769  0.56297]
#  [0.6816  0.56591]
#  [0.6844  0.56907]
#  [0.68534 0.56963]
#  [0.68802 0.57244]
#  [0.68851 0.57328]
#  [0.68886 0.5751 ]
#  [0.69053 0.57697]
# ...
